# %%
import numpy as np
import torch 
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt

# %%
# %matplotlib widget

# %%
imgs = np.load("/tmp/openai-2024-08-28-14-16-42-775192/samples_12x512x512x3.npz")

# %%
imgs.keys()
# Out:
# KeysView(NpzFile '/tmp/openai-2024-08-28-14-16-42-775192/samples_12x512x512x3.npz' with keys: arr_0, arr_1)

# %%
imgs['arr_0'].shape,imgs['arr_1']
# Out:
# ((12, 512, 512, 3),
#  array([754, 185, 283, 912, 779, 613, 585, 607, 487, 396, 474,  73]))

# %%
plt.figure()
plt.imshow(imgs['arr_0'][0])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
